# %%
using Plots

# %%
x = range(0, 10, length=100)
y = sin.(x)
# Out:
# 100-element Vector{Float64}:
#   0.0
#   0.1008384202581046
#   0.2006488565226854
#   0.2984138044476411
#   0.3931366121483298
#   0.48385164043793466
#   0.5696341069089657
#   0.6496095135057065
#   0.7229625614794605
#   0.7889454628442574
#   0.8468855636029834
#   0.8961922010299563
#   0.9363627251042848
#   ⋮
#   0.510605678474283
#   0.4213006405886069
#   0.32770070881349816
#   0.23076007532505177
#   0.13146698864295842
#   0.03083367906114098
#  -0.07011396040064677
#  -0.1703468323280965
#  -0.26884312591038406
#  -0.3645987336558887
#  -0.45663748763377376
#  -0.5440211108893698

# %%
plot(x, y)
